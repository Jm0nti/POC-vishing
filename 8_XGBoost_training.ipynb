# %% [markdown]
# # XGBoost Experimentation — Vishing Detection
#
# Pipeline dedicated to exploring XGBoost variations, the algorithm that showed the best performance in the multi-model pipeline of Notebook 7.
#
# ## Strategy
# - **7 XGBoost variants** covering different hyperparameter axes
# - Each variant is trained on **13 augmented-data datasets** (12 balanced + 1 raw 1M)
# - Each variant is trained on **13 original-data datasets** (12 balanced + 1 raw 50K)
# - Separate hold-out per data type (augmented: 200K | original: 10K)
# - Models serialized as `VishingModelWrapper` in `s3://poc-fraude-vishing/proyecto/modelos_xgb/`
#
# ## XGBoost Variants
# | Variant | Description |
# |---|---|
# | `xgb_base` | Same configuration as Notebook 7 (baseline) |
# | `xgb_deep` | Deeper trees, more estimators, low lr |
# | `xgb_shallow` | Shallow trees, many estimators (classic boosting) |
# | `xgb_regularized` | Strong regularization (L1 + L2 + high min_child_weight) |
# | `xgb_balanced` | `scale_pos_weight` adapted to the dataset's real imbalance |
# | `xgb_conservative` | Aggressive subsampling (subsample + colsample_bytree + gamma) |
# | `xgb_slow_learner` | Very low learning rate with 500 estimators |

# %%
# %pip install --quiet "sagemaker<3"
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import copy
import json as _json
import joblib
import warnings
from io import BytesIO
from pathlib import Path
from urllib.parse import urlparse

import boto3
import sagemaker

from xgboost import XGBClassifier

from sklearn.metrics import (
    recall_score, precision_score, f1_score,
    roc_auc_score, average_precision_score,
    confusion_matrix, precision_recall_curve,
)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

warnings.filterwarnings('ignore')
print('Libraries loaded successfully.')
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# Libraries loaded successfully.

# %% [markdown]
# ## 1. Environment configuration

# %%
sagemaker_session = sagemaker.Session()
role              = sagemaker.get_execution_role()
s3_client         = boto3.client('s3')

BUCKET       = 'poc-fraude-vishing'
BASE_PREFIX  = 'proyecto'
DATA_PREFIX  = f'{BASE_PREFIX}/data'
MODELS_PREFIX = f'{BASE_PREFIX}/modelos_xgb'   # new path, does not overwrite notebook 7

COLS_TO_DROP = [
    'session_id', 'customer_id', 'session_timestamp',
    'device_type', 'os_type', 'app_version',
    'biocatch_risk_score', 'biocatch_genuine_score',
    'biocatch_ato_indicator', 'biocatch_social_eng_indicator', 'biocatch_bot_indicator',
    'days_to_claim', 'claim_category',
    'screens_visited', 'unusual_screen_visits',
    'is_synthetic', 'interactions_per_s',
]

print(f'Bucket  : {BUCKET}')
print(f'Models  : s3://{BUCKET}/{MODELS_PREFIX}/')
print(f'Role    : {role}')
# Out:
# Bucket  : poc-fraude-vishing
# Models  : s3://poc-fraude-vishing/proyecto/modelos_xgb/
# Role    : arn:aws:iam::538430999815:role/demo-moe

# %% [markdown]
# ## 2. XGBoost variant definitions
#
# Each dictionary entry defines the **fixed** hyperparameters of the variant.
# The `xgb_balanced` variant is special: its `scale_pos_weight` is computed at training time from the real imbalance of each dataset.

# %%
COMMON = dict(
    tree_method='hist',
    device='cuda',
    eval_metric='logloss',
    random_state=42,
    use_label_encoder=False,
)

XGB_VARIANTS = {
    # Baseline identical to Notebook 7
    'xgb_base': dict(
        **COMMON,
        n_estimators=100,
        max_depth=6,
        learning_rate=0.1,
    ),
    # Deeper trees + more iterations + low lr
    'xgb_deep': dict(
        **COMMON,
        n_estimators=300,
        max_depth=9,
        learning_rate=0.05,
        min_child_weight=3,
    ),
    # Classic boosting: simple trees, many iterations
    'xgb_shallow': dict(
        **COMMON,
        n_estimators=500,
        max_depth=3,
        learning_rate=0.05,
    ),
    # Strong regularization — reduces overfitting on synthetic data
    'xgb_regularized': dict(
        **COMMON,
        n_estimators=200,
        max_depth=6,
        learning_rate=0.1,
        reg_alpha=1.0,      # L1
        reg_lambda=5.0,     # L2
        min_child_weight=10,
        gamma=0.3,
    ),
    # scale_pos_weight computed dynamically per dataset
    # (marked with None here; replaced in the loop)
    'xgb_balanced': dict(
        **COMMON,
        n_estimators=200,
        max_depth=6,
        learning_rate=0.1,
        scale_pos_weight=None,  # placeholder — computed per dataset
    ),
    # Aggressive subsampling — stochastic regularization
    'xgb_conservative': dict(
        **COMMON,
        n_estimators=200,
        max_depth=5,
        learning_rate=0.08,
        subsample=0.7,
        colsample_bytree=0.7,
        gamma=0.5,
        min_child_weight=5,
    ),
    # Slow learning with many estimators
    'xgb_slow_learner': dict(
        **COMMON,
        n_estimators=500,
        max_depth=6,
        learning_rate=0.01,
        subsample=0.8,
        colsample_bytree=0.8,
    ),
}

print(f'{len(XGB_VARIANTS)} variants defined:')
for name, params in XGB_VARIANTS.items():
    summary = {k: v for k, v in params.items()
               if k not in ('tree_method', 'device', 'eval_metric', 'random_state', 'use_label_encoder')}
    print(f'  {name:20s} → {summary}')
# Out:
# 7 variants defined:
#   xgb_base             → {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.1}
#   xgb_deep             → {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.05, 'min_child_weight': 3}
#   xgb_shallow          → {'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.05}
#   xgb_regularized      → {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.1, 'reg_alpha': 1.0, 'reg_lambda': 5.0, 'min_child_weight': 10, 'gamma': 0.3}
#   xgb_balanced         → {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.1, 'scale_pos_weight': None}
#   xgb_conservative     → {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.08, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.5, 'min_child_weight': 5}
#   xgb_slow_learner     → {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8}

# %% [markdown]
# ## 3. VishingModelWrapper

# %%
class VishingModelWrapper:
    """
    Bundles a trained XGBoost model with its feature list and optimal
    decision threshold. Accepts dict, JSON string, or list[dict] as input.
    """

    def __init__(self, model, feature_names, threshold=0.5,
                 model_name='', technique='', ratio='', data_type=''):
        self.model         = model
        self.feature_names = list(feature_names)
        self.threshold     = threshold
        self.model_name    = model_name
        self.technique     = technique
        self.ratio         = ratio
        self.data_type     = data_type  # 'augmented' | 'original'

    def _to_array(self, json_input):
        if isinstance(json_input, str):
            data = _json.loads(json_input)
        elif isinstance(json_input, dict):
            data = json_input
        elif isinstance(json_input, list):
            return np.vstack([self._to_array(item) for item in json_input])
        else:
            raise TypeError(f'Expected dict, JSON string, or list. Got {type(json_input)}')
        missing = set(self.feature_names) - set(data.keys())
        if missing:
            raise ValueError(f'Missing features: {sorted(missing)}')
        return np.array([[data[f] for f in self.feature_names]], dtype=np.float64)

    def predict(self, json_input):
        proba  = self.model.predict_proba(self._to_array(json_input))[:, 1]
        labels = (proba >= self.threshold).astype(int).tolist()
        return labels[0] if len(labels) == 1 else labels

    def predict_proba_raw(self, json_input):
        proba = self.model.predict_proba(self._to_array(json_input))
        rows  = [{'legitimate': round(float(p[0]), 6), 'vishing': round(float(p[1]), 6)}
                 for p in proba]
        return rows[0] if len(rows) == 1 else rows

    def predict_full(self, json_input):
        proba   = self.model.predict_proba(self._to_array(json_input))
        results = []
        for p in proba:
            label = int(p[1] >= self.threshold)
            results.append({
                'prediction':             label,
                'label':                  'vishing' if label == 1 else 'legitimate',
                'probability_vishing':    round(float(p[1]), 6),
                'probability_legitimate': round(float(p[0]), 6),
                'threshold_used':         round(self.threshold, 6),
            })
        return results[0] if len(results) == 1 else results

    def __repr__(self):
        return (f'VishingModelWrapper(variant={self.model_name!r}, '
                f'data={self.data_type!r}, technique={self.technique!r}, '
                f'ratio={self.ratio!r}, n_features={len(self.feature_names)}, '
                f'threshold={self.threshold:.4f})')

# %% [markdown]
# ## 4. Helper function: training a variant on a dataset

# %%
def train_and_evaluate(variant_name, variant_params, X_train, y_train,
                       X_test, y_test, feature_names,
                       technique, ratio, data_type):
    """
    Trains an XGBoost variant, computes metrics on the holdout,
    serializes the wrapper, and uploads it to S3.
    Returns the metrics dict.
    """
    params = copy.deepcopy(variant_params)

    # xgb_balanced: scale_pos_weight computed from the training set
    if params.get('scale_pos_weight') is None:
        n_neg = int((y_train == 0).sum())
        n_pos = int((y_train == 1).sum())
        params['scale_pos_weight'] = round(n_neg / max(n_pos, 1), 2)

    model = XGBClassifier(**params)
    model.fit(X_train, y_train, verbose=False)

    y_prob = model.predict_proba(X_test)[:, 1]

    # Optimal threshold by max F1
    prec_arr, rec_arr, thr_arr = precision_recall_curve(y_test, y_prob)
    f1_arr  = 2 * prec_arr[:-1] * rec_arr[:-1] / (prec_arr[:-1] + rec_arr[:-1] + 1e-9)
    opt_thr = float(thr_arr[np.argmax(f1_arr)])
    y_pred  = (y_prob >= opt_thr).astype(int)

    # Package
    wrapper = VishingModelWrapper(
        model        = model,
        feature_names= feature_names,
        threshold    = opt_thr,
        model_name   = variant_name,
        technique    = technique,
        ratio        = ratio,
        data_type    = data_type,
    )

    # Upload to S3
    s3_key  = f'{MODELS_PREFIX}/{data_type}/{variant_name}/{technique}/{ratio}.pkl'
    buf     = BytesIO()
    joblib.dump(wrapper, buf)
    buf.seek(0)
    s3_client.upload_fileobj(buf, BUCKET, s3_key)

    return {
        'Variant'    : variant_name,
        'Data_Type'  : data_type,
        'Technique'  : technique,
        'Ratio'      : ratio,
        'Threshold'  : round(opt_thr, 4),
        'Recall'     : round(recall_score(y_test, y_pred), 4),
        'Precision'  : round(precision_score(y_test, y_pred), 4),
        'F1'         : round(f1_score(y_test, y_pred), 4),
        'ROC_AUC'    : round(roc_auc_score(y_test, y_prob), 4),
        'PR_AUC'     : round(average_precision_score(y_test, y_prob), 4),
        'S3_Path'    : f's3://{BUCKET}/{s3_key}',
        'scale_pos_weight': params.get('scale_pos_weight', 'N/A'),
    }

print('Function train_and_evaluate defined.')
# Out:
# Function train_and_evaluate defined.

# %% [markdown]
# ## 5. Augmented Dataset (1M sessions)
# ### 5.1 Loading the augmented raw + hold-out extraction

# %%
S3_AUG_PATH = f's3://{BUCKET}/{DATA_PREFIX}/augmented_data/dataset_1M_vishing_ctgan.parquet'
print(f'Loading: {S3_AUG_PATH}')

df_aug = pd.read_parquet(S3_AUG_PATH)
df_aug = df_aug.drop(columns=[c for c in COLS_TO_DROP if c in df_aug.columns])

X_aug = df_aug.drop(columns=['is_vishing'])
y_aug = df_aug['is_vishing']

_, X_test_aug, _, y_test_aug = train_test_split(
    X_aug, y_aug, test_size=0.20, random_state=42, stratify=y_aug
)

FEATURE_NAMES = X_test_aug.columns.tolist()

n = len(df_aug)
nv = int(y_aug.sum())
print(f'\nAugmented dataset  : {n:,} rows  |  vishing {nv/n*100:.2f}%')
print(f'Augmented hold-out : {len(X_test_aug):,} rows  |  vishing {y_test_aug.mean()*100:.2f}%')
print(f'Features           : {len(FEATURE_NAMES)}')
# Out:
# Loading: s3://poc-fraude-vishing/proyecto/data/augmented_data/dataset_1M_vishing_ctgan.parquet
#
# Augmented dataset  : 1,000,000 rows  |  vishing 1.50%
# Augmented hold-out : 200,000 rows  |  vishing 1.50%
# Features           : 44

# %% [markdown]
# ### 5.2 Listing of the 13 balanced augmented-data datasets

# %%
prefix_balanced_aug = f'{DATA_PREFIX}/balanced/augmented/'
response = s3_client.list_objects_v2(Bucket=BUCKET, Prefix=prefix_balanced_aug)

aug_paths = sorted([
    f"s3://{BUCKET}/{obj['Key']}"
    for obj in response.get('Contents', [])
    if obj['Key'].endswith('.parquet')
])

# Add augmented raw as dataset #13
aug_paths.append(S3_AUG_PATH)

print(f'Augmented-data datasets: {len(aug_paths)}')
for p in aug_paths:
    print(f'  {p}')
# Out:
# Augmented-data datasets: 13
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/borderline_smote/10.parquet
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/borderline_smote/20.parquet
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/borderline_smote/25.parquet
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/random_oversampling/10.parquet
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/random_oversampling/20.parquet
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/random_oversampling/25.parquet
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/smote/10.parquet
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/smote/20.parquet
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/smote/25.parquet
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/smote_undersampling/10.parquet
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/smote_undersampling/20.parquet
#   s3://poc-fraude-vishing/proyecto/data/balanced/augmented/smote_undersampling/25.parquet
#   s3://poc-fraude-vishing/proyecto/data/augmented_data/dataset_1M_vishing_ctgan.parquet

# %% [markdown]
# ### 5.3 Training loop — augmented data
# 7 variants × 13 datasets = **91 models**

# %%
results = []

total_aug = len(aug_paths) * len(XGB_VARIANTS)
done_aug  = 0

for path in aug_paths:
    parts     = urlparse(path).path.lstrip('/').split('/')
    technique = parts[-2]
    ratio     = Path(parts[-1]).stem

    df_train = pd.read_parquet(path)
    df_train = df_train.drop(columns=[c for c in COLS_TO_DROP if c in df_train.columns], errors='ignore')
    df_train = df_train.drop(index=X_test_aug.index, errors='ignore')  # exclude holdout rows

    X_tr = df_train.drop(columns=['is_vishing'])[FEATURE_NAMES]
    y_tr = df_train['is_vishing']

    for variant_name, variant_params in XGB_VARIANTS.items():
        done_aug += 1
        print(f'[{done_aug:3d}/{total_aug}] {technique:25s} | {ratio:30s} | {variant_name}', end=' ... ')

        row = train_and_evaluate(
            variant_name   = variant_name,
            variant_params = variant_params,
            X_train        = X_tr.values,
            y_train        = y_tr.values,
            X_test         = X_test_aug[FEATURE_NAMES].values,
            y_test         = y_test_aug.values,
            feature_names  = FEATURE_NAMES,
            technique      = technique,
            ratio          = ratio,
            data_type      = 'augmented',
        )
        results.append(row)
        print(f"Recall={row['Recall']:.3f}  PR-AUC={row['PR_AUC']:.3f}")

print('\n✅ Augmented-data training loop completed.')
# Out:
# [  1/91] borderline_smote          | 10                             | xgb_base ... Recall=0.544  PR-AUC=0.606
# [  2/91] borderline_smote          | 10                             | xgb_deep ... Recall=0.608  PR-AUC=0.709
# [  3/91] borderline_smote          | 10                             | xgb_shallow ... Recall=0.528  PR-AUC=0.594
# [  4/91] borderline_smote          | 10                             | xgb_regularized ... Recall=0.618  PR-AUC=0.682
# [  5/91] borderline_smote          | 10                             | xgb_balanced ... Recall=0.609  PR-AUC=0.687
# [  6/91] borderline_smote          | 10                             | xgb_conservative ... Recall=0.571  PR-AUC=0.638
# [  7/91] borderline_smote          | 10                             | xgb_slow_learner ... Recall=0.423  PR-AUC=0.495
# [  8/91] borderline_smote          | 20                             | xgb_base ... Recall=0.500  PR-AUC=0.572
# [  9/91] borderline_smote          | 20                             | xgb_deep ... Recall=0.580  PR-AUC=0.700
# [ 10/91] borderline_smote          | 20                             | xgb_shallow ... Recall=0.486  PR-AUC=0.555
# [ 11/91] borderline_smote          | 20                             | xgb_regularized ... Recall=0.571  PR-AUC=0.664
# [ 12/91] borderline_smote          | 20                             | xgb_balanced ... Recall=0.591  PR-AUC=0.666
# [ 13/91] borderline_smote          | 20                             | xgb_conservative ... Recall=0.511  PR-AUC=0.611
# [ 14/91] borderline_smote          | 20                             | xgb_slow_learner ... Recall=0.420  PR-AUC=0.441
# [ 15/91] borderline_smote          | 25                             | xgb_base ... Recall=0.480  PR-AUC=0.554
# [ 16/91] borderline_smote          | 25                             | xgb_deep ... Recall=0.604  PR-AUC=0.700
# [ 17/91] borderline_smote          | 25                             | xgb_shallow ... Recall=0.494  PR-AUC=0.535
# [ 18/91] borderline_smote          | 25                             | xgb_regularized ... Recall=0.555  PR-AUC=0.653
# [ 19/91] borderline_smote          | 25                             | xgb_balanced ... Recall=0.557  PR-AUC=0.657
# [ 20/91] borderline_smote          | 25                             | xgb_conservative ... Recall=0.518  PR-AUC=0.596
# [ 21/91] borderline_smote          | 25                             | xgb_slow_learner ... Recall=0.409  PR-AUC=0.429
# [ 22/91] random_oversampling       | 10                             | xgb_base ... Recall=0.619  PR-AUC=0.700
# [ 23/91] random_oversampling       | 10                             | xgb_deep ... Recall=0.797  PR-AUC=0.887
# [ 24/91] random_oversampling       | 10                             | xgb_shallow ... Recall=0.597  PR-AUC=0.647
# [ 25/91] random_oversampling       | 10                             | xgb_regularized ... Recall=0.665  PR-AUC=0.755
# [ 26/91] random_oversampling       | 10                             | xgb_balanced ... Recall=0.667  PR-AUC=0.760
# [ 27/91] random_oversampling       | 10                             | xgb_conservative ... Recall=0.626  PR-AUC=0.706
# [ 28/91] random_oversampling       | 10                             | xgb_slow_learner ... Recall=0.558  PR-AUC=0.628
# [ 29/91] random_oversampling       | 20                             | xgb_base ... Recall=0.622  PR-AUC=0.704
# [ 30/91] random_oversampling       | 20                             | xgb_deep ... Recall=0.810  PR-AUC=0.896
# [ 31/91] random_oversampling       | 20                             | xgb_shallow ... Recall=0.608  PR-AUC=0.648
# [ 32/91] random_oversampling       | 20                             | xgb_regularized ... Recall=0.665  PR-AUC=0.758
# [ 33/91] random_oversampling       | 20                             | xgb_balanced ... Recall=0.661  PR-AUC=0.765
# [ 34/91] random_oversampling       | 20                             | xgb_conservative ... Recall=0.640  PR-AUC=0.709
# [ 35/91] random_oversampling       | 20                             | xgb_slow_learner ... Recall=0.538  PR-AUC=0.630
# [ 36/91] random_oversampling       | 25                             | xgb_base ... Recall=0.625  PR-AUC=0.704
# [ 37/91] random_oversampling       | 25                             | xgb_deep ... Recall=0.801  PR-AUC=0.895
# [ 38/91] random_oversampling       | 25                             | xgb_shallow ... Recall=0.565  PR-AUC=0.645
# [ 39/91] random_oversampling       | 25                             | xgb_regularized ... Recall=0.668  PR-AUC=0.761
# [ 40/91] random_oversampling       | 25                             | xgb_balanced ... Recall=0.676  PR-AUC=0.767
# [ 41/91] random_oversampling       | 25                             | xgb_conservative ... Recall=0.626  PR-AUC=0.709
# [ 42/91] random_oversampling       | 25                             | xgb_slow_learner ... Recall=0.552  PR-AUC=0.631
# [ 43/91] smote                     | 10                             | xgb_base ... Recall=0.517  PR-AUC=0.608
# [ 44/91] smote                     | 10                             | xgb_deep ... Recall=0.627  PR-AUC=0.710
# [ 45/91] smote                     | 10                             | xgb_shallow ... Recall=0.534  PR-AUC=0.599
# [ 46/91] smote                     | 10                             | xgb_regularized ... Recall=0.582  PR-AUC=0.689
# [ 47/91] smote                     | 10                             | xgb_balanced ... Recall=0.592  PR-AUC=0.688
# [ 48/91] smote                     | 10                             | xgb_conservative ... Recall=0.547  PR-AUC=0.646
# [ 49/91] smote                     | 10                             | xgb_slow_learner ... Recall=0.424  PR-AUC=0.500
# [ 50/91] smote                     | 20                             | xgb_base ... Recall=0.488  PR-AUC=0.577
# [ 51/91] smote                     | 20                             | xgb_deep ... Recall=0.597  PR-AUC=0.705
# [ 52/91] smote                     | 20                             | xgb_shallow ... Recall=0.476  PR-AUC=0.552
# [ 53/91] smote                     | 20                             | xgb_regularized ... Recall=0.605  PR-AUC=0.664
# [ 54/91] smote                     | 20                             | xgb_balanced ... Recall=0.557  PR-AUC=0.669
# [ 55/91] smote                     | 20                             | xgb_conservative ... Recall=0.507  PR-AUC=0.608
# [ 56/91] smote                     | 20                             | xgb_slow_learner ... Recall=0.396  PR-AUC=0.451
# [ 57/91] smote                     | 25                             | xgb_base ... Recall=0.465  PR-AUC=0.555
# [ 58/91] smote                     | 25                             | xgb_deep ... Recall=0.626  PR-AUC=0.703
# [ 59/91] smote                     | 25                             | xgb_shallow ... Recall=0.460  PR-AUC=0.533
# [ 60/91] smote                     | 25                             | xgb_regularized ... Recall=0.559  PR-AUC=0.657
# [ 61/91] smote                     | 25                             | xgb_balanced ... Recall=0.585  PR-AUC=0.656
# [ 62/91] smote                     | 25                             | xgb_conservative ... Recall=0.513  PR-AUC=0.591
# [ 63/91] smote                     | 25                             | xgb_slow_learner ... Recall=0.402  PR-AUC=0.438
# [ 64/91] smote_undersampling       | 10                             | xgb_base ... Recall=0.565  PR-AUC=0.651
# [ 65/91] smote_undersampling       | 10                             | xgb_deep ... Recall=0.750  PR-AUC=0.848
# [ 66/91] smote_undersampling       | 10                             | xgb_shallow ... Recall=0.566  PR-AUC=0.614
# [ 67/91] smote_undersampling       | 10                             | xgb_regularized ... Recall=0.649  PR-AUC=0.734
# [ 68/91] smote_undersampling       | 10                             | xgb_balanced ... Recall=0.640  PR-AUC=0.741
# [ 69/91] smote_undersampling       | 10                             | xgb_conservative ... Recall=0.584  PR-AUC=0.670
# [ 70/91] smote_undersampling       | 10                             | xgb_slow_learner ... Recall=0.450  PR-AUC=0.530
# [ 71/91] smote_undersampling       | 20                             | xgb_base ... Recall=0.520  PR-AUC=0.594
# [ 72/91] smote_undersampling       | 20                             | xgb_deep ... Recall=0.712  PR-AUC=0.818
# [ 73/91] smote_undersampling       | 20                             | xgb_shallow ... Recall=0.512  PR-AUC=0.562
# [ 74/91] smote_undersampling       | 20                             | xgb_regularized ... Recall=0.600  PR-AUC=0.700
# [ 75/91] smote_undersampling       | 20                             | xgb_balanced ... Recall=0.608  PR-AUC=0.708
# [ 76/91] smote_undersampling       | 20                             | xgb_conservative ... Recall=0.550  PR-AUC=0.625
# [ 77/91] smote_undersampling       | 20                             | xgb_slow_learner ... Recall=0.413  PR-AUC=0.466
# [ 78/91] smote_undersampling       | 25                             | xgb_base ... Recall=0.490  PR-AUC=0.582
# [ 79/91] smote_undersampling       | 25                             | xgb_deep ... Recall=0.707  PR-AUC=0.805
# [ 80/91] smote_undersampling       | 25                             | xgb_shallow ... Recall=0.459  PR-AUC=0.548
# [ 81/91] smote_undersampling       | 25                             | xgb_regularized ... Recall=0.577  PR-AUC=0.692
# [ 82/91] smote_undersampling       | 25                             | xgb_balanced ... Recall=0.613  PR-AUC=0.699
# [ 83/91] smote_undersampling       | 25                             | xgb_conservative ... Recall=0.527  PR-AUC=0.613
# [ 84/91] smote_undersampling       | 25                             | xgb_slow_learner ... Recall=0.378  PR-AUC=0.449
# [ 85/91] augmented_data            | dataset_1M_vishing_ctgan       | xgb_base ... Recall=0.593  PR-AUC=0.654
# [ 86/91] augmented_data            | dataset_1M_vishing_ctgan       | xgb_deep ... Recall=0.552  PR-AUC=0.676
# [ 87/91] augmented_data            | dataset_1M_vishing_ctgan       | xgb_shallow ... Recall=0.579  PR-AUC=0.633
# [ 88/91] augmented_data            | dataset_1M_vishing_ctgan       | xgb_regularized ... Recall=0.585  PR-AUC=0.690
# [ 89/91] augmented_data            | dataset_1M_vishing_ctgan       | xgb_balanced ... Recall=0.591  PR-AUC=0.693
# [ 90/91] augmented_data            | dataset_1M_vishing_ctgan       | xgb_conservative ... Recall=0.604  PR-AUC=0.670
# [ 91/91] augmented_data            | dataset_1M_vishing_ctgan       | xgb_slow_learner ... Recall=0.519  PR-AUC=0.593
#
# ✅ Augmented-data training loop completed.

# %% [markdown]
# ## 6. Original Dataset (50K sessions)
# ### 6.1 Loading the original raw + hold-out extraction

# %%
S3_ORIG_RAW_PATH = f's3://{BUCKET}/{BASE_PREFIX}/raw_data/biocatch_sinthetic_data.csv'
print(f'Loading: {S3_ORIG_RAW_PATH}')

df_orig = pd.read_csv(S3_ORIG_RAW_PATH)
df_orig = df_orig.drop(columns=[c for c in COLS_TO_DROP if c in df_orig.columns])

X_orig = df_orig.drop(columns=['is_vishing'])
y_orig = df_orig['is_vishing']

# Align to the same feature order as the augmented data
shared_feats = [f for f in FEATURE_NAMES if f in X_orig.columns]
X_orig = X_orig[shared_feats]

_, X_test_orig, _, y_test_orig = train_test_split(
    X_orig, y_orig, test_size=0.20, random_state=42, stratify=y_orig
)

FEATURE_NAMES_ORIG = shared_feats

n = len(df_orig)
nv = int(y_orig.sum())
print(f'\nOriginal dataset  : {n:,} rows  |  vishing {nv/n*100:.2f}%')
print(f'Original hold-out : {len(X_test_orig):,} rows  |  vishing {y_test_orig.mean()*100:.2f}%')
print(f'Features          : {len(FEATURE_NAMES_ORIG)}')
# Out:
# Loading: s3://poc-fraude-vishing/proyecto/raw_data/biocatch_sinthetic_data.csv
#
# Original dataset  : 50,000 rows  |  vishing 5.00%
# Original hold-out : 10,000 rows  |  vishing 5.00%
# Features          : 44

# %% [markdown]
# ### 6.2 Listing of the 13 original-data datasets

# %%
prefix_balanced_orig = f'{BASE_PREFIX}/data/balanced/original/'
response_orig = s3_client.list_objects_v2(Bucket=BUCKET, Prefix=prefix_balanced_orig)

orig_paths = sorted([
    f"s3://{BUCKET}/{obj['Key']}"
    for obj in response_orig.get('Contents', [])
    if obj['Key'].endswith('.csv')
])

# Add original raw as dataset #13
orig_paths.append(S3_ORIG_RAW_PATH)

print(f'Original-data datasets: {len(orig_paths)}')
for p in orig_paths:
    print(f'  {p}')
# Out:
# Original-data datasets: 13
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/borderline_smote/10.csv
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/borderline_smote/20.csv
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/borderline_smote/25.csv
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/random_oversampling/10.csv
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/random_oversampling/20.csv
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/random_oversampling/25.csv
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/smote/10.csv
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/smote/20.csv
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/smote/25.csv
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/smote_undersampling/10.csv
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/smote_undersampling/20.csv
#   s3://poc-fraude-vishing/proyecto/data/balanced/original/smote_undersampling/25.csv
#   s3://poc-fraude-vishing/proyecto/raw_data/biocatch_sinthetic_data.csv

# %% [markdown]
# ### 6.3 Training loop — original data
# 7 variants × 13 datasets = **91 models**

# %%
total_orig = len(orig_paths) * len(XGB_VARIANTS)
done_orig  = 0

for path in orig_paths:
    parsed    = urlparse(path).path.lstrip('/')
    parts     = parsed.split('/')
    technique = parts[-2]
    ratio     = Path(parts[-1]).stem

    if path.endswith('.csv'):
        df_train = pd.read_csv(path)
    else:
        df_train = pd.read_parquet(path)

    df_train = df_train.drop(columns=[c for c in COLS_TO_DROP if c in df_train.columns], errors='ignore')

    # Exclude rows that belong to the original raw hold-out
    df_train = df_train.drop(index=X_test_orig.index, errors='ignore')

    X_tr = df_train.drop(columns=['is_vishing'])
    # Keep only shared features, in the same order
    X_tr = X_tr[[f for f in FEATURE_NAMES_ORIG if f in X_tr.columns]]
    y_tr = df_train['is_vishing']

    feat_names_ds = X_tr.columns.tolist()

    for variant_name, variant_params in XGB_VARIANTS.items():
        done_orig += 1
        print(f'[{done_orig:3d}/{total_orig}] {technique:25s} | {ratio:30s} | {variant_name}', end=' ... ')

        row = train_and_evaluate(
            variant_name   = variant_name,
            variant_params = variant_params,
            X_train        = X_tr.values,
            y_train        = y_tr.values,
            X_test         = X_test_orig[feat_names_ds].values,
            y_test         = y_test_orig.values,
            feature_names  = feat_names_ds,
            technique      = technique,
            ratio          = ratio,
            data_type      = 'original',
        )
        results.append(row)
        print(f"Recall={row['Recall']:.3f}  PR-AUC={row['PR_AUC']:.3f}")

print('\n✅ Original-data training loop completed.')
# Out:
# [  1/91] borderline_smote          | 10                             | xgb_base ... Recall=0.460  PR-AUC=0.115
# [  2/91] borderline_smote          | 10                             | xgb_deep ... Recall=0.274  PR-AUC=0.159
# [  3/91] borderline_smote          | 10                             | xgb_shallow ... Recall=0.400  PR-AUC=0.115
# [  4/91] borderline_smote          | 10                             | xgb_regularized ... Recall=0.350  PR-AUC=0.121
# [  5/91] borderline_smote          | 10                             | xgb_balanced ... Recall=0.346  PR-AUC=0.114
# [  6/91] borderline_smote          | 10                             | xgb_conservative ... Recall=0.374  PR-AUC=0.112
# [  7/91] borderline_smote          | 10                             | xgb_slow_learner ... Recall=0.450  PR-AUC=0.111
# [  8/91] borderline_smote          | 20                             | xgb_base ... Recall=0.376  PR-AUC=0.117
# [  9/91] borderline_smote          | 20                             | xgb_deep ... Recall=0.336  PR-AUC=0.198
# [ 10/91] borderline_smote          | 20                             | xgb_shallow ... Recall=0.488  PR-AUC=0.100
# [ 11/91] borderline_smote          | 20                             | xgb_regularized ... Recall=0.406  PR-AUC=0.126
# [ 12/91] borderline_smote          | 20                             | xgb_balanced ... Recall=0.304  PR-AUC=0.130
# [ 13/91] borderline_smote          | 20                             | xgb_conservative ... Recall=0.286  PR-AUC=0.106
# [ 14/91] borderline_smote          | 20                             | xgb_slow_learner ... Recall=0.450  PR-AUC=0.111
# [ 15/91] borderline_smote          | 25                             | xgb_base ... Recall=0.356  PR-AUC=0.116
# [ 16/91] borderline_smote          | 25                             | xgb_deep ... Recall=0.348  PR-AUC=0.198
# [ 17/91] borderline_smote          | 25                             | xgb_shallow ... Recall=0.352  PR-AUC=0.098
# [ 18/91] borderline_smote          | 25                             | xgb_regularized ... Recall=0.446  PR-AUC=0.121
# [ 19/91] borderline_smote          | 25                             | xgb_balanced ... Recall=0.358  PR-AUC=0.127
# [ 20/91] borderline_smote          | 25                             | xgb_conservative ... Recall=0.356  PR-AUC=0.108
# [ 21/91] borderline_smote          | 25                             | xgb_slow_learner ... Recall=0.430  PR-AUC=0.112
# [ 22/91] random_oversampling       | 10                             | xgb_base ... Recall=0.428  PR-AUC=0.278
# [ 23/91] random_oversampling       | 10                             | xgb_deep ... Recall=0.598  PR-AUC=0.720
# [ 24/91] random_oversampling       | 10                             | xgb_shallow ... Recall=0.462  PR-AUC=0.168
# [ 25/91] random_oversampling       | 10                             | xgb_regularized ... Recall=0.530  PR-AUC=0.397
# [ 26/91] random_oversampling       | 10                             | xgb_balanced ... Recall=0.452  PR-AUC=0.438
# [ 27/91] random_oversampling       | 10                             | xgb_conservative ... Recall=0.524  PR-AUC=0.251
# [ 28/91] random_oversampling       | 10                             | xgb_slow_learner ... Recall=0.262  PR-AUC=0.241
# [ 29/91] random_oversampling       | 20                             | xgb_base ... Recall=0.390  PR-AUC=0.367
# [ 30/91] random_oversampling       | 20                             | xgb_deep ... Recall=0.870  PR-AUC=0.930
# [ 31/91] random_oversampling       | 20                             | xgb_shallow ... Recall=0.488  PR-AUC=0.196
# [ 32/91] random_oversampling       | 20                             | xgb_regularized ... Recall=0.582  PR-AUC=0.502
# [ 33/91] random_oversampling       | 20                             | xgb_balanced ... Recall=0.528  PR-AUC=0.572
# [ 34/91] random_oversampling       | 20                             | xgb_conservative ... Recall=0.498  PR-AUC=0.309
# [ 35/91] random_oversampling       | 20                             | xgb_slow_learner ... Recall=0.310  PR-AUC=0.303
# [ 36/91] random_oversampling       | 25                             | xgb_base ... Recall=0.458  PR-AUC=0.370
# [ 37/91] random_oversampling       | 25                             | xgb_deep ... Recall=0.878  PR-AUC=0.948
# [ 38/91] random_oversampling       | 25                             | xgb_shallow ... Recall=0.368  PR-AUC=0.204
# [ 39/91] random_oversampling       | 25                             | xgb_regularized ... Recall=0.542  PR-AUC=0.534
# [ 40/91] random_oversampling       | 25                             | xgb_balanced ... Recall=0.642  PR-AUC=0.588
# [ 41/91] random_oversampling       | 25                             | xgb_conservative ... Recall=0.458  PR-AUC=0.341
# [ 42/91] random_oversampling       | 25                             | xgb_slow_learner ... Recall=0.306  PR-AUC=0.311
# [ 43/91] smote                     | 10                             | xgb_base ... Recall=0.392  PR-AUC=0.106
# [ 44/91] smote                     | 10                             | xgb_deep ... Recall=0.292  PR-AUC=0.143
# [ 45/91] smote                     | 10                             | xgb_shallow ... Recall=0.384  PR-AUC=0.106
# [ 46/91] smote                     | 10                             | xgb_regularized ... Recall=0.478  PR-AUC=0.115
# [ 47/91] smote                     | 10                             | xgb_balanced ... Recall=0.290  PR-AUC=0.112
# [ 48/91] smote                     | 10                             | xgb_conservative ... Recall=0.356  PR-AUC=0.103
# [ 49/91] smote                     | 10                             | xgb_slow_learner ... Recall=0.546  PR-AUC=0.110
# [ 50/91] smote                     | 20                             | xgb_base ... Recall=0.442  PR-AUC=0.106
# [ 51/91] smote                     | 20                             | xgb_deep ... Recall=0.330  PR-AUC=0.169
# [ 52/91] smote                     | 20                             | xgb_shallow ... Recall=0.364  PR-AUC=0.096
# [ 53/91] smote                     | 20                             | xgb_regularized ... Recall=0.370  PR-AUC=0.112
# [ 54/91] smote                     | 20                             | xgb_balanced ... Recall=0.334  PR-AUC=0.113
# [ 55/91] smote                     | 20                             | xgb_conservative ... Recall=0.420  PR-AUC=0.101
# [ 56/91] smote                     | 20                             | xgb_slow_learner ... Recall=0.380  PR-AUC=0.103
# [ 57/91] smote                     | 25                             | xgb_base ... Recall=0.432  PR-AUC=0.107
# [ 58/91] smote                     | 25                             | xgb_deep ... Recall=0.348  PR-AUC=0.192
# [ 59/91] smote                     | 25                             | xgb_shallow ... Recall=0.500  PR-AUC=0.090
# [ 60/91] smote                     | 25                             | xgb_regularized ... Recall=0.464  PR-AUC=0.113
# [ 61/91] smote                     | 25                             | xgb_balanced ... Recall=0.402  PR-AUC=0.118
# [ 62/91] smote                     | 25                             | xgb_conservative ... Recall=0.416  PR-AUC=0.100
# [ 63/91] smote                     | 25                             | xgb_slow_learner ... Recall=0.584  PR-AUC=0.104
# [ 64/91] smote_undersampling       | 10                             | xgb_base ... Recall=0.462  PR-AUC=0.334
# [ 65/91] smote_undersampling       | 10                             | xgb_deep ... Recall=0.790  PR-AUC=0.852
# [ 66/91] smote_undersampling       | 10                             | xgb_shallow ... Recall=0.338  PR-AUC=0.180
# [ 67/91] smote_undersampling       | 10                             | xgb_regularized ... Recall=0.528  PR-AUC=0.523
# [ 68/91] smote_undersampling       | 10                             | xgb_balanced ... Recall=0.560  PR-AUC=0.560
# [ 69/91] smote_undersampling       | 10                             | xgb_conservative ... Recall=0.374  PR-AUC=0.276
# [ 70/91] smote_undersampling       | 10                             | xgb_slow_learner ... Recall=0.500  PR-AUC=0.238
# [ 71/91] smote_undersampling       | 20                             | xgb_base ... Recall=0.668  PR-AUC=0.215
# [ 72/91] smote_undersampling       | 20                             | xgb_deep ... Recall=0.730  PR-AUC=0.778
# [ 73/91] smote_undersampling       | 20                             | xgb_shallow ... Recall=0.410  PR-AUC=0.123
# [ 74/91] smote_undersampling       | 20                             | xgb_regularized ... Recall=0.560  PR-AUC=0.293
# [ 75/91] smote_undersampling       | 20                             | xgb_balanced ... Recall=0.556  PR-AUC=0.373
# [ 76/91] smote_undersampling       | 20                             | xgb_conservative ... Recall=0.408  PR-AUC=0.167
# [ 77/91] smote_undersampling       | 20                             | xgb_slow_learner ... Recall=0.598  PR-AUC=0.152
# [ 78/91] smote_undersampling       | 25                             | xgb_base ... Recall=0.482  PR-AUC=0.194
# [ 79/91] smote_undersampling       | 25                             | xgb_deep ... Recall=0.686  PR-AUC=0.728
# [ 80/91] smote_undersampling       | 25                             | xgb_shallow ... Recall=0.306  PR-AUC=0.111
# [ 81/91] smote_undersampling       | 25                             | xgb_regularized ... Recall=0.546  PR-AUC=0.239
# [ 82/91] smote_undersampling       | 25                             | xgb_balanced ... Recall=0.646  PR-AUC=0.311
# [ 83/91] smote_undersampling       | 25                             | xgb_conservative ... Recall=0.400  PR-AUC=0.149
# [ 84/91] smote_undersampling       | 25                             | xgb_slow_learner ... Recall=0.412  PR-AUC=0.140
# [ 85/91] raw_data                  | biocatch_sinthetic_data        | xgb_base ... Recall=0.470  PR-AUC=0.100
# [ 86/91] raw_data                  | biocatch_sinthetic_data        | xgb_deep ... Recall=0.388  PR-AUC=0.081
# [ 87/91] raw_data                  | biocatch_sinthetic_data        | xgb_shallow ... Recall=0.418  PR-AUC=0.111
# [ 88/91] raw_data                  | biocatch_sinthetic_data        | xgb_regularized ... Recall=0.434  PR-AUC=0.099
# [ 89/91] raw_data                  | biocatch_sinthetic_data        | xgb_balanced ... Recall=0.354  PR-AUC=0.090
# [ 90/91] raw_data                  | biocatch_sinthetic_data        | xgb_conservative ... Recall=0.360  PR-AUC=0.101
# [ 91/91] raw_data                  | biocatch_sinthetic_data        | xgb_slow_learner ... Recall=0.518  PR-AUC=0.104
#
# ✅ Original-data training loop completed.

# %% [markdown]
# ## 7. Results Analysis
# ### 7.1 Full table sorted by PR-AUC

# %%
df_res = pd.DataFrame(results)

df_res_sorted = df_res.sort_values('PR_AUC', ascending=False)

print('=== TOP 20 combinations by PR-AUC ===')
display(
    df_res_sorted.head(20)
    [['Variant', 'Data_Type', 'Technique', 'Ratio', 'Recall', 'Precision', 'F1', 'ROC_AUC', 'PR_AUC', 'Threshold']]
    .style.background_gradient(cmap='YlOrRd', subset=['PR_AUC', 'Recall', 'ROC_AUC'])
    .format({'Recall': '{:.3f}', 'Precision': '{:.3f}', 'F1': '{:.3f}',
             'ROC_AUC': '{:.3f}', 'PR_AUC': '{:.3f}', 'Threshold': '{:.4f}'})
)
# Out:
# === TOP 20 combinations by PR-AUC ===
# <style type="text/css">
# #T_7249f_row0_col4, #T_7249f_row0_col8, #T_7249f_row2_col7, #T_7249f_row3_col7 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_7249f_row0_col7 {
#   background-color: #820026;
#   color: #f1f1f1;
# }
# #T_7249f_row1_col4 {
#   background-color: #8d0026;
#   color: #f1f1f1;
# }
# #T_7249f_row1_col7 {
#   background-color: #9f0026;
#   color: #f1f1f1;
# }
# #T_7249f_row1_col8 {
#   background-color: #a80026;
#   color: #f1f1f1;
# }
# #T_7249f_row2_col4 {
#   background-color: #e0181d;
#   color: #f1f1f1;
# }
# #T_7249f_row2_col8 {
#   background-color: #dc151e;
#   color: #f1f1f1;
# }
# #T_7249f_row3_col4 {
#   background-color: #e8241f;
#   color: #f1f1f1;
# }
# #T_7249f_row3_col8 {
#   background-color: #df171d;
#   color: #f1f1f1;
# }
# #T_7249f_row4_col4 {
#   background-color: #eb2b21;
#   color: #f1f1f1;
# }
# #T_7249f_row4_col7 {
#   background-color: #840026;
#   color: #f1f1f1;
# }
# #T_7249f_row4_col8 {
#   background-color: #e6211e;
#   color: #f1f1f1;
# }
# #T_7249f_row5_col4 {
#   background-color: #f03523;
#   color: #f1f1f1;
# }
# #T_7249f_row5_col7 {
#   background-color: #fd923e;
#   color: #000000;
# }
# #T_7249f_row5_col8 {
#   background-color: #fc6631;
#   color: #f1f1f1;
# }
# #T_7249f_row6_col4 {
#   background-color: #fd7836;
#   color: #f1f1f1;
# }
# #T_7249f_row6_col7 {
#   background-color: #990026;
#   color: #f1f1f1;
# }
# #T_7249f_row6_col8 {
#   background-color: #fd6e33;
#   color: #f1f1f1;
# }
# #T_7249f_row7_col4 {
#   background-color: #fea848;
#   color: #000000;
# }
# #T_7249f_row7_col7 {
#   background-color: #a60026;
#   color: #f1f1f1;
# }
# #T_7249f_row7_col8 {
#   background-color: #fea245;
#   color: #000000;
# }
# #T_7249f_row8_col4 {
#   background-color: #feae4a;
#   color: #000000;
# }
# #T_7249f_row8_col7 {
#   background-color: #ae0026;
#   color: #f1f1f1;
# }
# #T_7249f_row8_col8 {
#   background-color: #feb34d;
#   color: #000000;
# }
# #T_7249f_row9_col4 {
#   background-color: #fd9640;
#   color: #000000;
# }
# #T_7249f_row9_col7 {
#   background-color: #fc5d2e;
#   color: #f1f1f1;
# }
# #T_7249f_row9_col8, #T_7249f_row12_col4 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_7249f_row10_col4 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_7249f_row10_col7, #T_7249f_row12_col7 {
#   background-color: #b00026;
#   color: #f1f1f1;
# }
# #T_7249f_row10_col8 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_7249f_row11_col4 {
#   background-color: #fedd7f;
#   color: #000000;
# }
# #T_7249f_row11_col7 {
#   background-color: #b20026;
#   color: #f1f1f1;
# }
# #T_7249f_row11_col8 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_7249f_row12_col8 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_7249f_row13_col4 {
#   background-color: #feda78;
#   color: #000000;
# }
# #T_7249f_row13_col7, #T_7249f_row15_col7 {
#   background-color: #b60026;
#   color: #f1f1f1;
# }
# #T_7249f_row13_col8 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_7249f_row14_col4 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_7249f_row14_col7 {
#   background-color: #b40026;
#   color: #f1f1f1;
# }
# #T_7249f_row14_col8 {
#   background-color: #ffe793;
#   color: #000000;
# }
# #T_7249f_row15_col4 {
#   background-color: #fedb7b;
#   color: #000000;
# }
# #T_7249f_row15_col8, #T_7249f_row16_col4 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_7249f_row16_col7 {
#   background-color: #ca0923;
#   color: #f1f1f1;
# }
# #T_7249f_row16_col8 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_7249f_row17_col4 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_7249f_row17_col7 {
#   background-color: #cd0b22;
#   color: #f1f1f1;
# }
# #T_7249f_row17_col8 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_7249f_row18_col4 {
#   background-color: #fec561;
#   color: #000000;
# }
# #T_7249f_row18_col7 {
#   background-color: #fc5b2e;
#   color: #f1f1f1;
# }
# #T_7249f_row18_col8 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_7249f_row19_col4, #T_7249f_row19_col7, #T_7249f_row19_col8 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_7249f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7249f_level0_col0" class="col_heading level0 col0" >Variant</th>
#       <th id="T_7249f_level0_col1" class="col_heading level0 col1" >Data_Type</th>
#       <th id="T_7249f_level0_col2" class="col_heading level0 col2" >Technique</th>
#       <th id="T_7249f_level0_col3" class="col_heading level0 col3" >Ratio</th>
#       <th id="T_7249f_level0_col4" class="col_heading level0 col4" >Recall</th>
#       <th id="T_7249f_level0_col5" class="col_heading level0 col5" >Precision</th>
#       <th id="T_7249f_level0_col6" class="col_heading level0 col6" >F1</th>
#       <th id="T_7249f_level0_col7" class="col_heading level0 col7" >ROC_AUC</th>
#       <th id="T_7249f_level0_col8" class="col_heading level0 col8" >PR_AUC</th>
#       <th id="T_7249f_level0_col9" class="col_heading level0 col9" >Threshold</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7249f_level0_row0" class="row_heading level0 row0" >127</th>
#       <td id="T_7249f_row0_col0" class="data row0 col0" >xgb_deep</td>
#       <td id="T_7249f_row0_col1" class="data row0 col1" >original</td>
#       <td id="T_7249f_row0_col2" class="data row0 col2" >random_oversampling</td>
#       <td id="T_7249f_row0_col3" class="data row0 col3" >25</td>
#       <td id="T_7249f_row0_col4" class="data row0 col4" >0.878</td>
#       <td id="T_7249f_row0_col5" class="data row0 col5" >0.928</td>
#       <td id="T_7249f_row0_col6" class="data row0 col6" >0.902</td>
#       <td id="T_7249f_row0_col7" class="data row0 col7" >0.996</td>
#       <td id="T_7249f_row0_col8" class="data row0 col8" >0.948</td>
#       <td id="T_7249f_row0_col9" class="data row0 col9" >0.7264</td>
#     </tr>
#     <tr>
#       <th id="T_7249f_level0_row1" class="row_heading level0 row1" >120</th>
#       <td id="T_7249f_row1_col0" class="data row1 col0" >xgb_deep</td>
#       <td id="T_7249f_row1_col1" class="data row1 col1" >original</td>
#       <td id="T_7249f_row1_col2" class="data row1 col2" >random_oversampling</td>
#       <td id="T_7249f_row1_col3" class="data row1 col3" >20</td>
#       <td id="T_7249f_row1_col4" class="data row1 col4" >0.870</td>
#       <td id="T_7249f_row1_col5" class="data row1 col5" >0.902</td>
#       <td id="T_7249f_row1_col6" class="data row1 col6" >0.886</td>
#       <td id="T_7249f_row1_col7" class="data row1 col7" >0.991</td>
#       <td id="T_7249f_row1_col8" class="data row1 col8" >0.930</td>
#       <td id="T_7249f_row1_col9" class="data row1 col9" >0.6795</td>
#     </tr>
#     <tr>
#       <th id="T_7249f_level0_row2" class="row_heading level0 row2" >29</th>
#       <td id="T_7249f_row2_col0" class="data row2 col0" >xgb_deep</td>
#       <td id="T_7249f_row2_col1" class="data row2 col1" >augmented</td>
#       <td id="T_7249f_row2_col2" class="data row2 col2" >random_oversampling</td>
#       <td id="T_7249f_row2_col3" class="data row2 col3" >20</td>
#       <td id="T_7249f_row2_col4" class="data row2 col4" >0.810</td>
#       <td id="T_7249f_row2_col5" class="data row2 col5" >0.833</td>
#       <td id="T_7249f_row2_col6" class="data row2 col6" >0.822</td>
#       <td id="T_7249f_row2_col7" class="data row2 col7" >0.997</td>
#       <td id="T_7249f_row2_col8" class="data row2 col8" >0.896</td>
#       <td id="T_7249f_row2_col9" class="data row2 col9" >0.8826</td>
#     </tr>
#     <tr>
#       <th id="T_7249f_level0_row3" class="row_heading level0 row3" >36</th>
#       <td id="T_7249f_row3_col0" class="data row3 col0" >xgb_deep</td>
#       <td id="T_7249f_row3_col1" class="data row3 col1" >augmented</td>
#       <td id="T_7249f_row3_col2" class="data row3 col2" >random_oversampling</td>
#       <td id="T_7249f_row3_col3" class="data row3 col3" >25</td>
#       <td id="T_7249f_row3_col4" class="data row3 col4" >0.801</td>
#       <td id="T_7249f_row3_col5" class="data row3 col5" >0.837</td>
#       <td id="T_7249f_row3_col6" class="data row3 col6" >0.819</td>
#       <td id="T_7249f_row3_col7" class="data row3 col7" >0.997</td>
#       <td id="T_7249f_row3_col8" class="data row3 col8" >0.895</td>
#       <td id="T_7249f_row3_col9" class="data row3 col9" >0.8880</td>
#     </tr>
#     <tr>
#       <th id="T_7249f_level0_row4" class="row_heading level0 row4" >22</th>

# %% [markdown]
# ### 7.2 Best configuration per variant

# %%
best_per_variant = (
    df_res.sort_values('PR_AUC', ascending=False)
    .groupby(['Variant', 'Data_Type'], as_index=False)
    .first()
)

print('=== Best dataset per variant and data type ===')
display(
    best_per_variant
    [['Variant', 'Data_Type', 'Technique', 'Ratio', 'Recall', 'Precision', 'F1', 'PR_AUC']]
    .sort_values(['Data_Type', 'PR_AUC'], ascending=[True, False])
    .style.background_gradient(cmap='Blues', subset=['PR_AUC'])
    .format({'Recall': '{:.3f}', 'Precision': '{:.3f}', 'F1': '{:.3f}', 'PR_AUC': '{:.3f}'})
)
# Out:
# === Best dataset per variant and data type ===
# <style type="text/css">
# #T_09860_row0_col7 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_09860_row1_col7 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_09860_row2_col7 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_09860_row3_col7 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_09860_row4_col7 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_09860_row5_col7 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_09860_row6_col7 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_09860_row7_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_09860_row8_col7 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_09860_row9_col7 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_09860_row10_col7 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_09860_row11_col7 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_09860_row12_col7 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_09860_row13_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_09860">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09860_level0_col0" class="col_heading level0 col0" >Variant</th>
#       <th id="T_09860_level0_col1" class="col_heading level0 col1" >Data_Type</th>
#       <th id="T_09860_level0_col2" class="col_heading level0 col2" >Technique</th>
#       <th id="T_09860_level0_col3" class="col_heading level0 col3" >Ratio</th>
#       <th id="T_09860_level0_col4" class="col_heading level0 col4" >Recall</th>
#       <th id="T_09860_level0_col5" class="col_heading level0 col5" >Precision</th>
#       <th id="T_09860_level0_col6" class="col_heading level0 col6" >F1</th>
#       <th id="T_09860_level0_col7" class="col_heading level0 col7" >PR_AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09860_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_09860_row0_col0" class="data row0 col0" >xgb_deep</td>
#       <td id="T_09860_row0_col1" class="data row0 col1" >augmented</td>
#       <td id="T_09860_row0_col2" class="data row0 col2" >random_oversampling</td>
#       <td id="T_09860_row0_col3" class="data row0 col3" >20</td>
#       <td id="T_09860_row0_col4" class="data row0 col4" >0.810</td>
#       <td id="T_09860_row0_col5" class="data row0 col5" >0.833</td>
#       <td id="T_09860_row0_col6" class="data row0 col6" >0.822</td>
#       <td id="T_09860_row0_col7" class="data row0 col7" >0.896</td>
#     </tr>
#     <tr>
#       <th id="T_09860_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_09860_row1_col0" class="data row1 col0" >xgb_balanced</td>
#       <td id="T_09860_row1_col1" class="data row1 col1" >augmented</td>
#       <td id="T_09860_row1_col2" class="data row1 col2" >random_oversampling</td>
#       <td id="T_09860_row1_col3" class="data row1 col3" >25</td>
#       <td id="T_09860_row1_col4" class="data row1 col4" >0.676</td>
#       <td id="T_09860_row1_col5" class="data row1 col5" >0.748</td>
#       <td id="T_09860_row1_col6" class="data row1 col6" >0.710</td>
#       <td id="T_09860_row1_col7" class="data row1 col7" >0.767</td>
#     </tr>
#     <tr>
#       <th id="T_09860_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_09860_row2_col0" class="data row2 col0" >xgb_regularized</td>
#       <td id="T_09860_row2_col1" class="data row2 col1" >augmented</td>
#       <td id="T_09860_row2_col2" class="data row2 col2" >random_oversampling</td>
#       <td id="T_09860_row2_col3" class="data row2 col3" >25</td>
#       <td id="T_09860_row2_col4" class="data row2 col4" >0.668</td>
#       <td id="T_09860_row2_col5" class="data row2 col5" >0.751</td>
#       <td id="T_09860_row2_col6" class="data row2 col6" >0.707</td>
#       <td id="T_09860_row2_col7" class="data row2 col7" >0.761</td>
#     </tr>
#     <tr>
#       <th id="T_09860_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_09860_row3_col0" class="data row3 col0" >xgb_conservative</td>
#       <td id="T_09860_row3_col1" class="data row3 col1" >augmented</td>
#       <td id="T_09860_row3_col2" class="data row3 col2" >random_oversampling</td>
#       <td id="T_09860_row3_col3" class="data row3 col3" >20</td>
#       <td id="T_09860_row3_col4" class="data row3 col4" >0.640</td>
#       <td id="T_09860_row3_col5" class="data row3 col5" >0.704</td>
#       <td id="T_09860_row3_col6" class="data row3 col6" >0.670</td>
#       <td id="T_09860_row3_col7" class="data row3 col7" >0.709</td>
#     </tr>
#     <tr>
#       <th id="T_09860_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_09860_row4_col0" class="data row4 col0" >xgb_base</td>
#       <td id="T_09860_row4_col1" class="data row4 col1" >augmented</td>
#       <td id="T_09860_row4_col2" class="data row4 col2" >random_oversampling</td>
#       <td id="T_09860_row4_col3" class="data row4 col3" >20</td>
#       <td id="T_09860_row4_col4" class="data row4 col4" >0.622</td>
#       <td id="T_09860_row4_col5" class="data row4 col5" >0.699</td>
#       <td id="T_09860_row4_col6" class="data row4 col6" >0.659</td>
#       <td id="T_09860_row4_col7" class="data row4 col7" >0.704</td>
#     </tr>
#     <tr>
#       <th id="T_09860_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_09860_row5_col0" class="data row5 col0" >xgb_shallow</td>
#       <td id="T_09860_row5_col1" class="data row5 col1" >augmented</td>
#       <td id="T_09860_row5_col2" class="data row5 col2" >random_oversampling</td>
#       <td id="T_09860_row5_col3" class="data row5 col3" >20</td>
#       <td id="T_09860_row5_col4" class="data row5 col4" >0.608</td>
#       <td id="T_09860_row5_col5" class="data row5 col5" >0.640</td>
#       <td id="T_09860_row5_col6" class="data row5 col6" >0.624</td>
#       <td id="T_09860_row5_col7" class="data row5 col7" >0.648</td>
#     </tr>
#     <tr>
#       <th id="T_09860_level0_row6" class="row_heading level0 row6" >12</th>
#       <td id="T_09860_row6_col0" class="data row6 col0" >xgb_slow_learner</td>
#       <td id="T_09860_row6_col1" class="data row6 col1" >augmented</td>
#       <td id="T_09860_row6_col2" class="data row6 col2" >random_oversampling</td>
#       <td id="T_09860_row6_col3" class="data row6 col3" >25</td>
#       <td id="T_09860_row6_col4" class="data row6 col4" >0.552</td>
#       <td id="T_09860_row6_col5" class="data row6 col5" >0.656</td>
#       <td id="T_09860_row6_col6" class="data row6 col6" >0.599</td>
#       <td id="T_09860_row6_col7" class="data row6 col7" >0.631</td>
#     </tr>
#     <tr>
#       <th id="T_09860_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_09860_row7_col0" class="data row7 col0" >xgb_deep</td>
#       <td id="T_09860_row7_col1" class="data row7 col1" >original</td>
#       <td id="T_09860_row7_col2" class="data row7 col2" >random_oversampling</td>
#       <td id="T_09860_row7_col3" class="data row7 col3" >25</td>
#       <td id="T_09860_row7_col4" class="data row7 col4" >0.878</td>
#       <td id="T_09860_row7_col5" class="data row7 col5" >0.928</td>
#       <td id="T_09860_row7_col6" class="data row7 col6" >0.902</td>
#       <td id="T_09860_row7_col7" class="data row7 col7" >0.948</td>
#     </tr>
#     <tr>
#       <th id="T_09860_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_09860_row8_col0" class="data row8 col0" >xgb_balanced</td>
#       <td id="T_09860_row8_col1" class="data row8 col1" >original</td>
#       <td id="T_09860_row8_col2" class="data row8 col2" >random_oversampling</td>
#       <td id="T_09860_row8_col3" class="data row8 col3" >25</td>
#       <td id="T_09860_row8_col4" class="data row8 col4" >0.642</td>
#       <td id="T_09860_row8_col5" class="data row8 col5" >0.498</td>
#       <td id="T_09860_row8_col6" class="data row8 col6" >0.561</td>
#       <td id="T_09860_row8_col7" class="data row8 col7" >0.588</td>
#     </tr>
#     <tr>
#       <th id="T_09860_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_09860_row9_col0" class="data row9 col0" >xgb_regularized</td>
#       <td id="T_09860_row9_col1" class="data row9 col1" >original</td>
#       <td id="T_09860_row9_col2" class="data row9 co

# %% [markdown]
# ### 7.3 Visual comparison of variants

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

metrics = ['PR_AUC', 'Recall', 'F1', 'ROC_AUC']
titles  = ['PR-AUC (main metric)', 'Recall', 'F1-Score', 'ROC-AUC']

for ax, metric, title in zip(axes.flat, metrics, titles):
    pivot = (
        df_res.groupby(['Variant', 'Data_Type'])[metric]
        .mean()
        .reset_index()
    )
    sns.barplot(data=pivot, x='Variant', y=metric, hue='Data_Type',
                palette={'augmented': '#3498db', 'original': '#e74c3c'}, ax=ax)
    ax.set_title(title, fontweight='bold')
    ax.set_xlabel('')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='right')
    ax.legend(title='Data type')

plt.suptitle('XGBoost variant comparison — Mean over all datasets',
             fontsize=14, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

for ax, data_type in zip(axes, ['augmented', 'original']):
    sub = df_res[df_res['Data_Type'] == data_type]
    pivot = sub.groupby(['Variant', 'Technique'])['PR_AUC'].mean().reset_index()
    pivot_wide = pivot.pivot(index='Technique', columns='Variant', values='PR_AUC')
    sns.heatmap(pivot_wide, annot=True, fmt='.3f', cmap='YlOrRd',
                linewidths=0.5, ax=ax, cbar_kws={'label': 'PR-AUC'})
    ax.set_title(f'PR-AUC — {data_type.capitalize()} data\n(average over ratios)',
                 fontweight='bold')
    ax.set_xlabel('XGBoost variant')
    ax.set_ylabel('Balancing technique')
    ax.tick_params(axis='x', rotation=30)

plt.suptitle('PR-AUC Heatmap: Variant × Balancing Technique', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Best Global Model Analysis
# ### 8.1 Confusion matrix

# %%
best_row = df_res_sorted.iloc[0]
print(f"Best global combination (PR-AUC = {best_row['PR_AUC']:.4f})")
print(f"  Variant   : {best_row['Variant']}")
print(f"  Data type : {best_row['Data_Type']}")
print(f"  Technique : {best_row['Technique']}")
print(f"  Ratio     : {best_row['Ratio']}")
print(f"  Threshold : {best_row['Threshold']}")
print(f"  S3        : {best_row['S3_Path']}")

# Load wrapper from S3
parsed   = urlparse(best_row['S3_Path'])
s3_key   = parsed.path.lstrip('/')
buf      = BytesIO()
s3_client.download_fileobj(BUCKET, s3_key, buf)
buf.seek(0)
best_wrapper = joblib.load(buf)

# Correct holdout depending on data_type
if best_row['Data_Type'] == 'augmented':
    X_te, y_te = X_test_aug[best_wrapper.feature_names], y_test_aug
else:
    feat_ok = [f for f in best_wrapper.feature_names if f in X_test_orig.columns]
    X_te, y_te = X_test_orig[feat_ok], y_test_orig

y_prob_best = best_wrapper.model.predict_proba(X_te.values)[:, 1]
y_pred_best = (y_prob_best >= best_wrapper.threshold).astype(int)
cm = confusion_matrix(y_te, y_pred_best)
tn, fp, fn, tp = cm.ravel()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[0],
            xticklabels=['Legitimate', 'Vishing'], yticklabels=['Legitimate', 'Vishing'])
axes[0].set_title('Counts')
axes[0].set_ylabel('Actual')
axes[0].set_xlabel('Predicted')

cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)
sns.heatmap(cm_norm, annot=True, fmt='.2%', cmap='Blues', ax=axes[1],
            xticklabels=['Legitimate', 'Vishing'], yticklabels=['Legitimate', 'Vishing'])
axes[1].set_title('Normalized')
axes[1].set_ylabel('Actual')
axes[1].set_xlabel('Predicted')

plt.suptitle(f"{best_row['Variant']} · {best_row['Technique']} {best_row['Ratio']} · {best_row['Data_Type']}",
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

print(f'\nTN={tn:,}  FP={fp:,}  FN={fn:,}  TP={tp:,}')
print(f'Recall    : {tp/(tp+fn):.4f}')
print(f'Precision : {tp/(tp+fp):.4f}')
print(f'F1        : {2*tp/(2*tp+fp+fn):.4f}')
print(f'PR-AUC    : {average_precision_score(y_te, y_prob_best):.4f}')
# Out:
# Best global combination (PR-AUC = 0.9484)
#   Variant   : xgb_deep
#   Data type : original
#   Technique : random_oversampling
#   Ratio     : 25
#   Threshold : 0.7264
#   S3        : s3://poc-fraude-vishing/proyecto/modelos_xgb/original/xgb_deep/random_oversampling/25.pkl
# TN=9,466  FP=34  FN=61  TP=439
# Recall    : 0.8780
# Precision : 0.9281
# F1        : 0.9024
# PR-AUC    : 0.9484

# %% [markdown]
# ### 8.2 Precision-Recall curve and threshold analysis

# %%
prec_c, rec_c, thr_c = precision_recall_curve(y_te, y_prob_best)
f1_c   = 2 * prec_c[:-1] * rec_c[:-1] / (prec_c[:-1] + rec_c[:-1] + 1e-9)
best_i = np.argmax(f1_c)
pr_auc = average_precision_score(y_te, y_prob_best)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

axes[0].plot(rec_c, prec_c, color='#3498db', linewidth=2, label=f'PR-AUC = {pr_auc:.4f}')
axes[0].fill_between(rec_c, prec_c, alpha=0.08, color='#3498db')
axes[0].axhline(y=y_te.mean(), color='gray', linestyle='--', alpha=0.7,
                label=f'Baseline ({y_te.mean():.4f})')
axes[0].scatter([rec_c[best_i]], [prec_c[best_i]], s=100, color='red', zorder=5,
                label=f'F1 optimum (thr={thr_c[best_i]:.3f})')
axes[0].set_xlabel('Recall')
axes[0].set_ylabel('Precision')
axes[0].set_title('Precision-Recall Curve', fontweight='bold')
axes[0].legend(fontsize=9)
axes[0].set_xlim(0, 1)
axes[0].set_ylim(0, 1.05)

axes[1].plot(thr_c, prec_c[:-1], label='Precision', color='#2ecc71', linewidth=2)
axes[1].plot(thr_c, rec_c[:-1],  label='Recall',    color='#e74c3c', linewidth=2)
axes[1].plot(thr_c, f1_c,        label='F1',        color='#f39c12', linewidth=2, linestyle='--')
axes[1].axvline(x=thr_c[best_i], color='black', linestyle=':', alpha=0.8,
                label=f'F1 optimum = {thr_c[best_i]:.3f}')
axes[1].axvline(x=0.5, color='gray', linestyle=':', alpha=0.5, label='Default (0.5)')
axes[1].set_xlabel('Decision threshold')
axes[1].set_ylabel('Metric')
axes[1].set_title('Precision / Recall / F1 vs Threshold', fontweight='bold')
axes[1].legend(fontsize=9)
axes[1].set_xlim(0, 1)
axes[1].set_ylim(0, 1.05)

plt.suptitle(f"Threshold Analysis — {best_row['Variant']}", fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.3 Feature Importance of the best model

# %%
fi = pd.DataFrame({
    'feature'   : best_wrapper.feature_names,
    'importance': best_wrapper.model.feature_importances_,
}).sort_values('importance', ascending=False).reset_index(drop=True)

fig, ax = plt.subplots(figsize=(12, 10))
top25   = fi.head(25)

q80 = top25['importance'].quantile(0.80)
q60 = top25['importance'].quantile(0.60)
colors = ['#e74c3c' if v >= q80 else '#f39c12' if v >= q60 else '#3498db'
          for v in top25['importance']]

ax.barh(range(len(top25)), top25['importance'].values,
        color=colors, edgecolor='white', linewidth=0.5)
ax.set_yticks(range(len(top25)))
ax.set_yticklabels(top25['feature'].values)
ax.invert_yaxis()
ax.set_xlabel('Importance (Gain)')
ax.set_title(f'Feature Importance — {best_row["Variant"]}  |  Top 25', fontweight='bold', fontsize=13)

for i, v in enumerate(top25['importance'].values):
    ax.text(v + top25['importance'].max() * 0.005, i, f'{v:.4f}', va='center', fontsize=8)

ax.legend(handles=[
    mpatches.Patch(facecolor='#e74c3c', label='Top 20%'),
    mpatches.Patch(facecolor='#f39c12', label='Top 20-40%'),
    mpatches.Patch(facecolor='#3498db', label='Rest'),
], loc='lower right')

plt.tight_layout()
plt.show()

print('Top 15 features:')
print(f'{"Feature":40s} {"Importance":>12s}')
print('-' * 55)
for _, row in fi.head(15).iterrows():
    print(f"{row['feature']:40s} {row['importance']:12.4f}")
# Out:
# Top 15 features:
# Feature                                    Importance
# -------------------------------------------------------
# segmented_typing_ratio                         0.0657
# dead_time_periods                              0.0395
# remote_access_tool_detected                    0.0365
# max_hesitation_duration_s                      0.0358
# call_overlap_duration_s                        0.0346
# dead_time_ratio                                0.0343
# hesitation_count                               0.0329
# amount_field_corrections                       0.0323
# avg_hesitation_duration_s                      0.0302
# beneficiary_field_corrections                  0.0293
# total_dead_time_s                              0.0260
# transaction_amount_cop                         0.0251
# data_familiarity_score                         0.0229
# keystroke_variability                          0.0227
# swipe_speed_px_s                               0.0225

# %% [markdown]
# ## 9. Executive summary

# %%
print('=' * 70)
print('TRAINING SUMMARY')
print('=' * 70)
print(f'  Total models trained     : {len(df_res)}')
print(f'  XGBoost variants         : {df_res["Variant"].nunique()}')
print(f'  Augmented datasets       : {df_res[df_res["Data_Type"]=="augmented"]["Technique"].count() // df_res["Variant"].nunique()}')
print(f'  Original datasets        : {df_res[df_res["Data_Type"]=="original"]["Technique"].count() // df_res["Variant"].nunique()}')
print(f'  Models in S3             : s3://{BUCKET}/{MODELS_PREFIX}/')
print()

for data_type in ['augmented', 'original']:
    sub  = df_res[df_res['Data_Type'] == data_type]
    best = sub.sort_values('PR_AUC', ascending=False).iloc[0]
    print(f'  Best {data_type:10s} — {best["Variant"]:20s} | {best["Technique"]:25s} | ratio={best["Ratio"]:4s}')
    print(f'    PR-AUC={best["PR_AUC"]:.4f}  Recall={best["Recall"]:.4f}  F1={best["F1"]:.4f}')
    print()

print('=' * 70)
print(f'  Best global → {best_row["Variant"]} / {best_row["Data_Type"]} / {best_row["Technique"]} / {best_row["Ratio"]}')
print(f'  PR-AUC={best_row["PR_AUC"]:.4f}  Recall={best_row["Recall"]:.4f}  F1={best_row["F1"]:.4f}')
print('=' * 70)

# Save results table to S3
csv_buf = BytesIO()
df_res.sort_values('PR_AUC', ascending=False).to_csv(csv_buf, index=False)
csv_buf.seek(0)
results_key = f'{MODELS_PREFIX}/resultados_xgb_experimento.csv'
s3_client.upload_fileobj(csv_buf, BUCKET, results_key)
print(f'\nResults table saved to: s3://{BUCKET}/{results_key}')
# Out:
# ======================================================================
# TRAINING SUMMARY
# ======================================================================
#   Total models trained     : 182
#   XGBoost variants         : 7
#   Augmented datasets       : 13
#   Original datasets        : 13
#   Models in S3             : s3://poc-fraude-vishing/proyecto/modelos_xgb/
#
#   Best augmented  — xgb_deep             | random_oversampling       | ratio=20
#     PR-AUC=0.8964  Recall=0.8103  F1=0.8216
#
#   Best original   — xgb_deep             | random_oversampling       | ratio=25
#     PR-AUC=0.9484  Recall=0.8780  F1=0.9024
#
# ======================================================================
#   Best global → xgb_deep / original / random_oversampling / 25
#   PR-AUC=0.9484  Recall=0.8780  F1=0.9024
# ======================================================================
#
# Results table saved to: s3://poc-fraude-vishing/proyecto/modelos_xgb/resultados_xgb_experimento.csv
