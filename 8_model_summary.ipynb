# %%
import pickle
PATH = "artifacts/vishing_XGBoost.pkl"

with open(PATH, "rb") as f:
    model = pickle.load(f)

# Para modelos tipo scikit-learn
try:
    print(model.feature_names_in_)
except AttributeError:
    print("El modelo no tiene feature_names_in_")

# Alternativa para booster interno
booster = model.get_booster()
print(booster.feature_names)
